# %%
## Delt board og spil op i forskellige classes så man kan restarte uden at reloade board

import random
import pygame
import numpy as np
import cv2

class SnakeBoard:
    def __init__(self, width=15, height=15):
        self.width = width
        self.height = height
        self.SCALE = 10
        # pygame
        pygame.init()
        self.screen = pygame.display.set_mode((width * self.SCALE, height * self.SCALE))

    def quit(self):
        pygame.quit()   
        print("Quitting game...")


class SnakeGame:
    def __init__(self, snake_board, width=15, height=15):
        self.snake_board = snake_board
        self.screen = snake_board.screen
        self.width = snake_board.width
        self.height = snake_board.height
        startpos = (width // 2, height // 2)
        self.SCALE = snake_board.SCALE
        self.apple = (random.randint(0, height - 1), random.randint(0, width - 1))

        self.tail = [startpos]
        self.directions = {"up": (-1, 0), "down": (1, 0), "right": (0, 1), "left": (0, -1)}
        self.currentdir = None

        # pygame
        self.clock = pygame.time.Clock()
        self.running = True
        self.tick_counter = 0


    def capture_screen(self):
        # Get the dimensions of the game area
        game_rect = pygame.Rect(0, 0, self.width * self.SCALE, self.height * self.SCALE)

        # Capture the screen data
        screen_data = pygame.surfarray.array3d(self.screen.subsurface(game_rect))

        # Convert the screen data to a Pygame surface
        screen_surface = pygame.surfarray.make_surface(screen_data)

        # Resize the captured screen to 15x15 pixels
        resized_screen_surface = pygame.transform.scale(screen_surface, (15, 15))

        # Convert the resized surface to a NumPy array
        resized_screen_data = pygame.surfarray.array3d(resized_screen_surface)

        # Convert RGB to grayscale
        grayscale_data = cv2.cvtColor(resized_screen_data, cv2.COLOR_RGB2GRAY)

        # Flatten the array
        flattened_screen_data = grayscale_data.flatten()
        reshaped_data = np.reshape(grayscale_data, (15, 15))
        # Save the array to a text file
        np.savetxt('screen_data.txt', reshaped_data, fmt='%.2f', delimiter=',')

        # Return the processed screen data
        #return flattened_screen_data

    def ask_to_continue(self):
        font = pygame.font.Font(None, 20)
        text = font.render("Do you want to continue? (Y/N)", True, (255, 255, 255))
        self.screen.blit(text, (50, 50))
        pygame.display.flip()

        while True:
            for event in pygame.event.get():
                if event.type == pygame.KEYDOWN:
                    if event.key == pygame.K_y:
                        return True
                    elif event.key == pygame.K_n:
                        return False
    
    def end(self):
        print(f"You died!\nScore: {len(self.tail)}")
        self.running = False

    def run(self):
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                self.running = False

        keys = pygame.key.get_pressed()

        self.screen.fill((255, 0, 0))

        if keys[pygame.K_p]:
            self.end()
        
        # draw snake
        head = self.tail[-1]
        for point in self.tail[:-1]:  # snake tail
            pygame.draw.rect(self.screen, (20, 97, 18),
                            (point[1] * self.SCALE, point[0] * self.SCALE, self.SCALE, self.SCALE))
            
        pygame.draw.rect(self.screen, (42, 227, 39),
                        (head[1] * self.SCALE, head[0] * self.SCALE, self.SCALE, self.SCALE))  # snake head

        # draw apple
        pygame.draw.rect(self.screen, (255, 255, 255),
                        (self.apple[1] * self.SCALE, self.apple[0] * self.SCALE, self.SCALE, self.SCALE))

        pygame.display.flip()
        self.clock.tick(60)

        self.tick_counter += 1
        
    def action(self, actions = None, keys = None, human = False):
        if human:
            actions = [keys[pygame.K_UP], keys[pygame.K_DOWN], keys[pygame.K_RIGHT], keys[pygame.K_LEFT]]
        else:
            #actions = [round(a) for a in actions]
            actions = np.round(actions).astype(int)
        
        if self.currentdir in ["right", "left"]:
            if actions[0]:
                action = "up"
            elif actions[1]:
                action = "down"
            else:
                action = self.currentdir
        elif self.currentdir in ["up", "down"]:
            if actions[2]:
                action = "right"
            elif actions[3]:
                action = "left"
            else:
                action = self.currentdir
        else:
            if actions[0]:
                action = "up"
            elif actions[1]:
                action = "down"
            elif actions[2]:
                action = "right"
            elif actions[3]:
                action = "left"
            else:
                action = self.currentdir
        self.currentdir = action

        if action:
            new = (self.tail[-1][0] + self.directions[action][0], self.tail[-1][1] + self.directions[action][1])

            if new in self.tail:
                self.end()
            elif not (0 <= new[0] <= self.height) or not (0 <= new[1] <= self.width):
                self.end()
            
            self.tail.append(new)

            if new != self.apple:
                self.tail.pop(0)
            else: # eat apple
                newapple = (random.randint(0, self.height - 1), random.randint(0, self.width - 1))
                while newapple in self.tail: # prevent apples on the snake
                    newapple = (random.randint(0, self.height - 1), random.randint(0, self.width - 1))
                self.apple = newapple

# %%
board = SnakeBoard(15, 15)

def play_snake(board):

    while board:
        snek = SnakeGame(board)
        while snek.running:
            keys = pygame.key.get_pressed()
            snek.run()
            snek.capture_screen() # saves screen to file screen_data.txt
            if snek.tick_counter % 5 == 0:
                snek.action(keys=keys, human=True)

        
        if snek.ask_to_continue() == False:
            board.quit()
            break


play_snake(board)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 20
#      16             board.quit()
#      17             break
# ---> 20 play_snake(board)
#
# Cell In[5], line 9, in play_snake(board)
#       7 while snek.running:
#       8     keys = pygame.key.get_pressed()
# ----> 9     snek.run()
#      10     snek.capture_screen() # saves screen to file screen_data.txt
#      11     if snek.tick_counter % 5 == 0:
#
# Cell In[4], line 114, in SnakeGame.run(self)
#     110 pygame.draw.rect(self.screen, (255, 255, 255),
#     111                 (self.apple[1] * self.SCALE, self.apple[0] * self.SCALE, self.SCALE, self.SCALE))
#     113 pygame.display.flip()
# --> 114 self.clock.tick(60)
#     116 self.tick_counter += 1
#
# KeyboardInterrupt:

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

# Define the DQN model
model = tf.keras.Sequential([
    layers.Flatten(input_shape=(15, 15)),  # Flatten the 15x15 grid
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(4, activation='softmax')  # Output layer with softmax activation
])

# Compile the model (you can use different optimizers and loss functions)
model.compile(optimizer='adam', loss='mse')

# %%
# Q-learning parameters
epsilon = 0.2 # Exploration-exploitation trade-off
discount_factor = 0.9  # Discount factor for future rewards
learning_rate = 0.001  # Learning rate for the neural network



# Simulate pressing of key
def simulate_key_press(key):
    key_event = pygame.event.Event(pygame.KEYDOWN, key=key)
    pygame.event.post(key_event)



# Training loop
num_episodes = 10000
board = SnakeBoard(15, 15)
for episode in range(num_episodes):
    # Initialize the Snake game environment
    
    snek = SnakeGame(board)

    # Reset environment and get initial state
    state = np.loadtxt('screen_data.txt', delimiter=',', dtype=str)  # Load the captured screen data
    state = state.reshape((1, 15, 15))
    state = state.astype(float)  # Convert the loaded strings to float

    # Initialize episode variables
    total_reward = 0
    curr_reward = 0

    while snek.running:
        snek.run()
        snek.capture_screen()
   
        next_state = np.loadtxt('screen_data.txt', delimiter=',', dtype=str)  # Load the captured screen data
        next_state = next_state.reshape((1, 15, 15))
        next_state = next_state.astype(float)  # Convert the loaded strings to float
        

        if snek.tick_counter % 1 == 0:

            # Choose an action using epsilon-greedy strategy
            if np.random.rand() < epsilon:
                q_values = [0, 0, 0, 1] 
                random.shuffle(q_values) # Exploration: Random action
                print(f"random {q_values}")
            else:
                q_values = model.predict(next_state)
                q_values = q_values[0]
                #action = np.argmax(q_values)  # Action with the highest Q-value index
                print(f"model: {q_values}")
            snek.action(actions=q_values, human=False)

        # Calculate reward based on the number of instances of the value 65 (tail pixels)
        prev_reward = curr_reward
        curr_reward = np.sum(next_state == 65)
        reward = (curr_reward - prev_reward) * 20

        if snek.running == False:
            print("punish")
            reward -= 10
        total_reward += reward
        # Update the Q-value using the Q-learning update rule
        target = reward + discount_factor * np.max(model.predict(next_state))
        model.fit(state, np.array([[target]]), epochs=1, verbose=0)

        done = snek.running  # Set 'done' based on game state
        # Move to the next state
        state = next_state

        # Accumulate total reward
       

    # Print total reward for the episode
    print(f"Episode {episode + 1}/{num_episodes}, Total Reward: {total_reward}")

    # Ask the user if they want to continue playing
    simulate_key_press(pygame.K_y)
    if snek.ask_to_continue() == False:
        board.quit()
        break
# Out:
# 1/1 [==============================] - 0s 67ms/step
# model: [1.0000000e+00 1.3164390e-20 1.0192822e-33 1.3510819e-14]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1.000000e+00 4.814847e-31 0.000000e+00 0.000000e+00]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 7ms/step
# Episode 1/10000, Total Reward: -10
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# random [0, 0, 1, 0]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 0, 1, 0]
# 1/1 [==============================] - 0s 7ms/step
# random [1, 0, 0, 0]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 7ms/step
# Episode 2/10000, Total Reward: -10
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 7ms/step
# Episode 3/10000, Total Reward: -10
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 0, 0, 1]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 0, 1, 0]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 7ms/step
# Episode 4/10000, Total Reward: -10
# random [0, 0, 1, 0]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 0, 1, 0]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 7ms/step
# Episode 5/10000, Total Reward: -10
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 7ms/step
# Episode 6/10000, Total Reward: -10
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 0, 0, 1]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 0, 1, 0]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 7ms/step
# Episode 7/10000, Total Reward: -10
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# random [0, 0, 0, 1]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 0, 1, 0]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 8ms/step
# Episode 8/10000, Total Reward: -10
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# random [1, 0, 0, 0]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 1, 0, 0]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 0, 0, 1]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 1, 0, 0]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 0, 0, 1]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 7ms/step
# Episode 9/10000, Total Reward: -10
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 1, 0, 0]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 7ms/step
# Episode 10/10000, Total Reward: -10
# random [1, 0, 0, 0]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# random [1, 0, 0, 0]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 0, 1, 0]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 7ms/step
# Episode 11/10000, Total Reward: -10
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 2
# punish
# 1/1 [==============================] - 0s 7ms/step
# Episode 12/10000, Total Reward: 0
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# random [1, 0, 0, 0]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 7ms/step
# Episode 13/10000, Total Reward: -10
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 7ms/step
# Episode 14/10000, Total Reward: -10
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 7ms/step
# Episode 15/10000, Total Reward: -10
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 0, 0, 1]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 0, 1, 0]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 7ms/step
# Episode 16/10000, Total Reward: -10
# random [0, 0, 1, 0]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 0, 1, 0]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 7ms/step
# Episode 17/10000, Total Reward: -10
# random [0, 1, 0, 0]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 0, 1, 0]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 1, 0, 0]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 0, 1, 0]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 0, 1, 0]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# random [1, 0, 0, 0]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 0, 0, 1]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 0, 0, 1]
# punish
# 1/1 [==============================] - 0s 8ms/step
# Episode 18/10000, Total Reward: -10
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 1, 0, 0]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 7ms/step
# Episode 19/10000, Total Reward: -10
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# random [0, 0, 1, 0]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 0, 0, 1]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 10ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# random [0, 0, 0, 1]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 7ms/step
# Episode 20/10000, Total Reward: -10
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# random [1, 0, 0, 0]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 0, 0, 1]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 8ms/step
# Episode 21/10000, Total Reward: -10
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 0, 0, 1]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 0, 1, 0]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 8ms/step
# Episode 22/10000, Total Reward: -10
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 8ms/step
# Episode 23/10000, Total Reward: -10
# 1/1 [==============================] - 0s 9ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 1, 0, 0]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 8ms/step
# Episode 24/10000, Total Reward: -10
# random [0, 0, 1, 0]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 8ms/step
# Episode 25/10000, Total Reward: -10
# random [0, 1, 0, 0]
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# random [0, 1, 0, 0]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# random [0, 0, 0, 1]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 0, 0, 1]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 9ms/step
# random [0, 0, 0, 1]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 8ms/step
# Episode 26/10000, Total Reward: -10
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 8ms/step
# Episode 27/10000, Total Reward: -10
# random [1, 0, 0, 0]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 1, 0, 0]
# 1/1 [==============================] - 0s 8ms/step
# random [0, 0, 1, 0]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 0, 0, 1]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# random [0, 0, 0, 1]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 7ms/step
# Episode 28/10000, Total Reward: -10
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 8ms/step
# Episode 29/10000, Total Reward: -10
# random [0, 1, 0, 0]
# 1/1 [==============================] - 0s 8ms/step
# random [0, 0, 0, 1]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# random [0, 1, 0, 0]
# 1/1 [==============================] - 0s 7ms/step
# random [0, 1, 0, 0]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 8ms/step
# Episode 30/10000, Total Reward: -10
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# random [0, 0, 1, 0]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 8ms/step
# Episode 31/10000, Total Reward: -10
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# random [0, 1, 0, 0]
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# You died!
# Score: 1
# punish
# 1/1 [==============================] - 0s 8ms/step
# Episode 32/10000, Total Reward: -10
# 1/1 [==============================] - 0s 8ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# model: [1. 0. 0. 0.]
# 1/1 [==============================] - 0s 8ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 66
#      64 # Update the Q-value using the Q-learning update rule
#      65 target = reward + discount_factor * np.max(model.predict(next_state))
# ---> 66 model.fit(state, np.array([[target]]), epochs=1, verbose=0)
#      68 done = snek.running  # Set 'done' based on game state
#      69 # Move to the next state
#
# File ~/miniconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/lib/python3.11/site-packages/keras/src/engine/training.py:1794, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1787 (
#    1788     data_handler._initial_epoch,
#    1789     data_handler._initial_step,
#    1790 ) = self._maybe_load_initial_counters_from_ckpt(
#    1791     steps_per_epoch_inferred, initial_epoch
#    1792 )
#    1793 logs = None
# -> 1794 for epoch, iterator in data_handler.enumerate_epochs():
#    1795     self.reset_metrics()
#    1796     callbacks.on_epoch_begin(epoch)
#
# File ~/miniconda3/lib/python3.11/site-packages/keras/src/engine/data_adapter.py:1340, in DataHandler.enumerate_epochs(self)
#    1338 def enumerate_epochs(self):
#    1339     """Yields `(epoch, tf.data.Iterator)`."""
# -> 1340     with self._truncate_execution_to_epoch():
#    1341         data_iterator = iter(self._dataset)
#    1342         for epoch in range(self._initial_epoch, self._epochs):
#
# File ~/miniconda3/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~/miniconda3/lib/python3.11/site-packages/keras/src/engine/data_adapter.py:1363, in DataHandler._truncate_execution_to_epoch(self)
#    1358 """Truncates steps per execution to at most one epoch."""
#    1359 should_truncate = (
#    1360     self._inferred_steps is not None
#    1361     and self._steps_per_execution.numpy().item() > self._inferred_steps
#    1362 )
# -> 1363 original_value = self._steps_per_execution.numpy().item()
#    1364 try:
#    1365     if should_truncate:
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:689, in BaseResourceVariable.numpy(self)
#     687 def numpy(self):
#     688   if context.executing_eagerly():
# --> 689     return self.read_value().numpy()
#     690   raise NotImplementedError(
#     691       "numpy() is only available when eager execution is enabled.")
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:839, in BaseResourceVariable.read_value(self)
#     830 """Constructs an op which reads the value of this variable.
#     831
#     832 Should be used when there are multiple reads, or when it is desirable to
#    (...)
#     836   The value of the variable.
#     837 """
#     838 with ops.name_scope("Read"):
# --> 839   value = self._read_variable_op()
#     840 # Return an identity so it can get placed on whatever device the context
#     841 # specifies instead of the device where the variable is.
#     842 return array_ops.identity(value)
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:803, in BaseResourceVariable._read_variable_op(self, no_copy)
#     791 def _read_variable_op(self, no_copy=False):
#     792   """Reads the value of the variable.
#     793
#     794   If the variable is in copy-on-read mode and `no_copy` is True, the variable
#    (...)
#     801     The value of the variable.
#     802   """
# --> 803   variable_accessed(self)
#     805   def read_and_set_handle(no_copy):
#     806     if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:335, in variable_accessed(variable)
#     333   ops.get_default_graph().watch_variable(variable)
#     334 if variable.trainable:
# --> 335   tape.variable_accessed(variable)
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/eager/tape.py:83, in variable_accessed(variable)
#      77 def variable_accessed(variable):
#      78   """Notifies all tapes in the stack that a variable has been accessed.
#      79
#      80   Args:
#      81     variable: variable to be watched.
#      82   """
# ---> 83   variables = _variables_override(variable)
#      84   for var in variables:
#      85     pywrap_tfe.TFE_Py_TapeVariableAccessed(var)
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/distribute/distribute_lib.py:4214, in get_local_results_or_value_container(variable)
#    4213 def get_local_results_or_value_container(variable):
# -> 4214   strategy, context = get_strategy_and_replica_context()
#    4215   if context:
#    4216     return [strategy.extended.value_container(variable)]
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/distribute/distribute_lib.py:580, in get_strategy_and_replica_context()
#     579 def get_strategy_and_replica_context():
# --> 580   per_thread_mode = _get_per_thread_mode()
#     581   return (per_thread_mode.strategy, per_thread_mode.replica_context)
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/distribute/distribute_lib.py:388, in _get_per_thread_mode()
#     386 def _get_per_thread_mode():
#     387   try:
# --> 388     return ops.get_default_graph()._distribution_strategy_stack[-1]  # pylint: disable=protected-access
#     389   except (AttributeError, IndexError):
#     390     return _get_default_replica_mode()
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/framework/ops.py:5035, in get_default_graph()
#    5010 @tf_export(v1=["get_default_graph"])
#    5011 def get_default_graph() -> Graph:
#    5012   """Returns the default graph for the current thread.
#    5013
#    5014   The returned graph will be the innermost graph on which a
#    (...)
#    5033     The default `Graph` being used in the current thread.
#    5034   """
# -> 5035   return _default_graph_stack.get_default()
#
# File ~/miniconda3/lib/python3.11/site-packages/tensorflow/python/framework/ops.py:4544, in _DefaultGraphStack.get_default(self)
#    4541   super(_DefaultGraphStack, self).__init__()
#    4542   self._global_default_graph = None
# -> 4544 def get_default(self):
#    4545   """Override that returns a global default if the stack is empty."""
#    4546   if self.stack:
#
# KeyboardInterrupt:

# %%
q_values[0]
